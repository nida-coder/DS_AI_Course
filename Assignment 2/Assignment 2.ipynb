# %%
# Step 1: Import libraries
import pandas as pd

# Step 2: Load dataset
df = pd.read_csv("customer_churn_dataset.csv")

# Step 3: Show first 5 rows
print("🔹 First 5 rows of the dataset:")
print(df.head())
# Out:
# 🔹 First 5 rows of the dataset:
#    CustomerID  Age  Gender  Tenure  Usage Frequency  Support Calls  \
# 0           1   22  Female      25               14              4
# 1           2   41  Female      28               28              7
# 2           3   47    Male      27               10              2
# 3           4   35    Male       9               12              5
# 4           5   53  Female      58               24              9
#
#    Payment Delay Subscription Type Contract Length  Total Spend  \
# 0             27             Basic         Monthly          598
# 1             13          Standard         Monthly          584
# 2             29           Premium          Annual          757
# 3             17           Premium       Quarterly          232
# 4              2          Standard          Annual          533
#
#    Last Interaction  Churn
# 0                 9      1
# 1                20      0
# 2                21      0
# 3                18      0
# ...

# %%
print("\n📊 Shape before cleaning:", df.shape)
# Out:
# 📊 Shape before cleaning: (64374, 12)

# %%
duplicates = df.duplicated().sum()
print("\n🧩 Number of duplicate rows:", duplicates)

# Remove duplicates
df.drop_duplicates(inplace=True)
# Out:
# 🧩 Number of duplicate rows: 0

# %%
print("\n🔍 Missing values before handling:")
print(df.isnull().sum())
# Out:
# 🔍 Missing values before handling:
# CustomerID           0
# Age                  0
# Gender               0
# Tenure               0
# Usage Frequency      0
# Support Calls        0
# Payment Delay        0
# Subscription Type    0
# Contract Length      0
# Total Spend          0
# Last Interaction     0
# Churn                0
# dtype: int64

# %%
print("\n🔍 Missing values before handling:")
print(df.isnull().sum())

# Fill missing numeric values with median
numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns
for col in numeric_cols:
    df[col].fillna(df[col].median(), inplace=True)

# Fill missing categorical values with mode
categorical_cols = df.select_dtypes(include=['object']).columns
for col in categorical_cols:
    df[col].fillna(df[col].mode()[0], inplace=True)
# Out:
# 🔍 Missing values before handling:
# CustomerID           0
# Age                  0
# Gender               0
# Tenure               0
# Usage Frequency      0
# Support Calls        0
# Payment Delay        0
# Subscription Type    0
# Contract Length      0
# Total Spend          0
# Last Interaction     0
# Churn                0
# dtype: int64

# %%
# Step 7: Handle outliers (using IQR method for numeric columns)
for col in numeric_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_limit = Q1 - 1.5 * IQR
    upper_limit = Q3 + 1.5 * IQR
    df = df[(df[col] >= lower_limit) & (df[col] <= upper_limit)]

# %%
print("\n📉 Shape after cleaning:", df.shape)
# Out:
# 📉 Shape after cleaning: (64374, 12)

# %%
# Step 9: Save cleaned dataset
df.to_csv("cleaned_customer_churn_dataset.csv", index=False)

# %%
print("\n🧾 Before vs After Cleaning Report")
print("----------------------------------")
print(f"Rows before cleaning: {duplicates + df.shape[0]}")
print(f"Rows after cleaning: {df.shape[0]}")
print("Duplicates removed:", duplicates)
print("Cleaned file saved as: cleaned_customer_churn_dataset.csv")
# Out:
# 🧾 Before vs After Cleaning Report
# ----------------------------------
# Rows before cleaning: 64374
# Rows after cleaning: 64374
# Duplicates removed: 0
# Cleaned file saved as: cleaned_customer_churn_dataset.csv
